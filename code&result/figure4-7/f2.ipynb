# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

# %% [markdown]
# # GBDT classifier

# %%
compounds = ['1000315-10-3','1000150-45-1', '1000315-10-4', '1000149-94-5', '622-78-6', '1000152-34-3', '1000162-57-7']
metrics = ['Average Accuracy', 'Average Recall', 'Average Precision', 'Average F1 Score', 'Average AUC']
data = np.array([
    [0.0000, 0.0000, -1.2183, -3.8086, -7.4635, -3.8086, 0.0000],
    [0.0000, 0.0000, -2.8090, -3.3708, -9.5506, -1.6854, 0.0000],
    [0.0000, 0.0000, 0.0000, -4.7959, -3.7302, -7.4603, 0.0000],
    [0.0000, 0.0000, -1.5930, -3.0745, -7.7866, -3.8432, 0.0000],
    [0.0000, 0.0000, -1.3263, -0.5305, -10.7374, -2.9178, 0.0000]
])


x = np.arange(len(compounds))
width = 0.15

plt.figure(dpi=300)
fig, ax = plt.subplots(figsize=(12, 4.5))
colors = ['#F66F69', '#FEB3AE', '#FFC24B', '#1597A5', '#0E609D']

for i in range(len(metrics)):
    ax.bar(x + i * width, data[i], width=width, label=metrics[i], color=colors[i])

# ax.set_xlabel('Features', fontsize=14)
ax.set_ylabel('Percent change in performance', fontsize=14)
# ax.set_title('Performance Metrics for Different Compounds', fontsize=16)
ax.set_xticks(x + width * (len(metrics) - 1) / 2)
ax.set_xticklabels(compounds, fontsize=14)
ax.legend(fontsize=15)

ax.tick_params(axis='y', labelsize=14)


ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_linewidth(2)  
ax.spines['bottom'].set_linewidth(2)  
ax.tick_params(axis='y', which='both', width=2)  
ax.tick_params(axis='x', which='both', width=2)  

# plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.legend(loc='lower left')

plt.savefig("GBDT_f.png")
plt.savefig("GBDT_f.pdf")
plt.show()

# %% [markdown]
# # RFC classifier

# %%
compounds = ['4602-84-0', '590-86-3', '1014-60-4', '6114-18-7', '123-69-3', '1000152-34-3', '1000377-93-5']
metrics = ['Average Accuracy', 'Average Recall', 'Average Precision', 'Average F1 Score', 'Average AUC']
data = np.array([
    [7.06912322, 2.71788841, 1.267476806, 1.450411603, 4.35123481, 8.70246962, -0.182934797],
    [8.805031447, -2.51572327, -5.660377358, -5.031446541, -3.773584906, 10.6918239, -3.144654088],
    [4.115384615, 4.487179487, 4.487179487, 4.487179487, 7.051282051, 5.192307692, 1.705128205],
    [7.903331156, 1.815806662, -0.039190072, 0.483344219, 2.521227956, 9.379490529, -0.365774004],
    [0.510144928, -2.469565217, 1.669565217, 4.208695652, -0.35942029, 2.028985507, -3.547826087]
])


x = np.arange(len(compounds))
width = 0.15
plt.figure(dpi=300)
fig, ax = plt.subplots(figsize=(12, 4.5))
colors = ['#F66F69', '#FEB3AE', '#FFC24B', '#1597A5', '#0E609D']

for i in range(len(metrics)):
    ax.bar(x + i * width, data[i], width=width, label=metrics[i], color=colors[i])

# ax.set_xlabel('Features', fontsize=14)
ax.set_ylabel('Percent change in performance', fontsize=14)
# ax.set_title('Performance Metrics for Different Compounds', fontsize=16)
ax.set_xticks(x + width * (len(metrics) - 1) / 2)
ax.set_xticklabels(compounds, fontsize=14)
ax.legend(fontsize=15)
ax.tick_params(axis='y', labelsize=14)

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_linewidth(2)  
ax.spines['bottom'].set_linewidth(2)  
ax.tick_params(axis='y', which='both', width=2)  
ax.tick_params(axis='x', which='both', width=2)  

# plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.legend(loc='lower left')

plt.savefig("RFC_f.png")
plt.savefig("RFC_f.pdf")
plt.show()

# %% [markdown]
# # SVM classifier

# %%
compounds = ['17431-03-7', '505-10-2', '74685-45-3', '622-78-6', '60-12-8', '104-46-1', '98-85-1']
metrics = ['Average Accuracy', 'Average Recall', 'Average Precision', 'Average F1 Score', 'Average AUC']
data = np.array([
    [-21.6,-9.081690141,-20.34929577,-19.08732394,-28.01126761,-6.107042254,-6.107042254],
    [-45.93023256,-15.69767442,-41.27906977,-34.30232558,-50.58139535,-2.325581395,-2.325581395],
    [-17.4863388,-0.863387978,-9.289617486,-1.453551913,-56.09836066,-6.327868852,-6.327868852],
    [-39.95220756,-11.72052799,-34.67228038,-27.41238052,-53.64132909,-4.949931725,-4.949931725],
    [0.526315789,1.052631579,0,0,-90.38947368,-0.526315789,-0.526315789]
])


x = np.arange(len(compounds))
width = 0.15
plt.figure(dpi=300)
fig, ax = plt.subplots(figsize=(12, 4.5))
colors = ['#F66F69', '#FEB3AE', '#FFC24B', '#1597A5', '#0E609D']

for i in range(len(metrics)):
    ax.bar(x + i * width, data[i], width=width, label=metrics[i], color=colors[i])

# ax.set_xlabel('Features', fontsize=14)
ax.set_ylabel('Percent change in performance', fontsize=14)
# ax.set_title('Performance Metrics for Different Compounds', fontsize=16)
ax.set_xticks(x + width * (len(metrics) - 1) / 2)
ax.set_xticklabels(compounds, fontsize=14)
ax.legend(fontsize=15)
ax.tick_params(axis='y', labelsize=14)

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_linewidth(2)  
ax.spines['bottom'].set_linewidth(2)  
ax.tick_params(axis='y', which='both', width=2)  
ax.tick_params(axis='x', which='both', width=2)  

# plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.legend(loc='lower left')

plt.savefig("SVM_f.png")
plt.savefig("SVM_f.pdf")
plt.show()

# %% [markdown]
# # 4 7 feature model representations

# %%
import matplotlib.pyplot as plt
import numpy as np

models = ['RFC', 'GDBT', 'SVM']
metrics = ['Average Accuracy', 'Average Recall', 'Average Precision', 'Average F1 Score', 'Average AUC']
data = {
    'RFC': [0.7653, 0.795, 0.78, 0.7655, 0.8625, 0.7875, 0.84, 0.7921, 0.7916, 0.8587],
    'GDBT': [0.9111, 0.89, 0.9383, 0.8977, 0.9425, 0.8889, 0.865, 0.925, 0.8745, 0.92],
    'SVM': [0.8875, 0.86, 0.915, 0.8788, 0.95, 0.6625, 0.625, 0.8181, 0.5842, 0.9475]
}


x = np.arange(len(models))
width = 0.15

plt.figure(figsize=(12, 6))
for i, metric in enumerate(metrics):
    plt.bar(x + i * width, [data[model][i] for model in models], width=width, label=metric)

plt.xlabel('Models', fontsize=14)
plt.ylabel('Metrics', fontsize=14)
plt.title('Performance Metrics for Different Models', fontsize=16)
plt.xticks(x + width * (len(metrics) - 1) / 2, models, fontsize=12)
plt.yticks(fontsize=12)
plt.legend(loc='upper right', fontsize=12)

plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Regression model train and test

# %%
data = {
    'Model': ['RFR', 'RFR', 'RFR', 'RFR', 'RFR', 'RFR', 'RFR', 'RFR', 
              'GDBT', 'GDBT', 'GDBT', 'GDBT', 'GDBT', 'GDBT', 'GDBT', 'GDBT', 
              'SVM', 'SVM', 'SVM', 'SVM', 'SVM', 'SVM',  'SVM', 'SVM', 
              'KNR', 'KNR', 'KNR', 'KNR', 'KNR', 'KNR','KNR', 'KNR'],
    'Data': ['Train', 'Train', 'Train', 'Train', 'Test', 'Test', 'Test', 'Test']*4,
    'Index': ['Average MSE', 'Average RMSE', 'Average MAE', 'Average PCC']*8,
    # 'Value': [0.0037766, 0.0606657, 0.0356404, 0.9766772, 0.0154723, 0.1195217, 0.0836457, 0.90662, 
    #           0.0379948, 0.1948672, 0.1214206, 0.8006665, 0.0470718, 0.2156946, 0.1365041, 0.7518207, 
    #           0.0062329, 0.0786776, 0.0448417, 0.9740391, 0.0097467, 0.0954139, 0.0551681, 0.9596133, 
    #           0.0071536, 0.0840788, 0.0445109, 0.9690515, 0.010047, 0.0957569, 0.0518318, 0.9576052]
    'Value': [  0.0056478,0.0741514,0.0416357,0.9655980,0.0168407,0.1260033,0.0888400,0.8968592, 
            0.0381115,0.1951637,0.1214878,0.7998916,0.0473075,0.2161795,0.1369431,0.750951, 
            0.0033278,0.0576302,0.0370544,0.9885443,0.0102305,0.0997389,0.0567776,0.9581679, 
            0.0071027,0.0837994,0.0440876,0.9692377,0.0096914,0.0940199,0.0497568,0.9588605]
}

df = pd.DataFrame(data)
df
# Out:
#    Model   Data         Index     Value
# 0    RFR  Train   Average MSE  0.003777
# 1    RFR  Train  Average RMSE  0.060666
# 2    RFR  Train   Average MAE  0.035640
# 3    RFR  Train   Average PCC  0.976677
# 4    RFR   Test   Average MSE  0.015472
# 5    RFR   Test  Average RMSE  0.119522
# 6    RFR   Test   Average MAE  0.083646
# 7    RFR   Test   Average PCC  0.906620
# 8   GDBT  Train   Average MSE  0.037995
# 9   GDBT  Train  Average RMSE  0.194867
# 10  GDBT  Train   Average MAE  0.121421
# 11  GDBT  Train   Average PCC  0.800666
# 12  GDBT   Test   Average MSE  0.047072
# 13  GDBT   Test  Average RMSE  0.215695
# 14  GDBT   Test   Average MAE  0.136504
# 15  GDBT   Test   Average PCC  0.751821
# 16   SVM  Train   Average MSE  0.006233
# 17   SVM  Train  Average RMSE  0.078678
# 18   SVM  Train   Average MAE  0.044842
# 19   SVM  Train   Average PCC  0.974039
# 20   SVM   Test   Average MSE  0.009747
# 21   SVM   Test  Average RMSE  0.095414
# ...

# %%
plt.rcdefaults()
plt.figure(figsize=(10, 8), dpi=300)

sns.catplot(data=df, x='Model', y='Value', hue='Data', col='Index', kind='bar',
            height=4, aspect=1, col_wrap=2, palette=['#F66F69', '#1597A5'])

for ax in plt.gcf().axes:
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_linewidth(2)
    ax.spines['bottom'].set_linewidth(2)
    ax.tick_params(axis='x', which='both', width=2)
    ax.tick_params(axis='y', which='both', width=2)
    ax.set_xlabel('Model', fontsize=14)
    ax.set_ylabel('Value', fontsize=14)
    ax.tick_params(axis='x', which='both', labelsize=14)
    ax.tick_params(axis='y', which='both', labelsize=14)
    ax.set_title(ax.get_title(), fontsize=14)
    ax.legend(fontsize=14)

plt.show()

# %%
import matplotlib.pyplot as plt


models = ['RFP', 'GDBT', 'SVM', 'KNR']
accuracy = [0.846153846, 0.769230769, 1, 0.923076923]
auc = [0.458333333, 0.875, 1, 0.5]


plt.figure(figsize=(6,3.5), dpi=300)

plt.plot(models, accuracy, marker='o',  markersize=10, label='Accuracy', color='#F66F69', linewidth=3)
plt.plot(models, auc, marker='*',  markersize=12, label='AUC', color='#1597A5', linewidth=3)

plt.ylim(0, 1.1)
plt.yticks([0, 0.25, 0.5, 0.75, 1], fontsize=12)
plt.xticks(fontsize=12)

plt.xlabel('Model', fontsize=14)
plt.ylabel('Value', fontsize=14)
# plt.title('Accuracy and AUC by Model', fontsize=14)
plt.legend(loc='lower right' ,fontsize=12)


plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

plt.gca().spines['left'].set_linewidth(2)
plt.gca().spines['bottom'].set_linewidth(2)

plt.gca().tick_params(axis='x', which='both', width=2)
plt.gca().tick_params(axis='y', which='both', width=2)
# plt.grid(axis='y', linestyle='--', alpha=0.5)

plt.axhline(y=0.5, color='gray', linestyle='--', linewidth=1, alpha=0.5)

plt.savefig("R_pred_AUC+ACC.png")
plt.savefig("R_pred_AUC+ACC.pdf")

plt.show()
